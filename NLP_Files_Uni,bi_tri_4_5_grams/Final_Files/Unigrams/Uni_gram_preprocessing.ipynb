# %%
import pandas as pd
data = pd.read_excel(r"C:\Users\sures\Downloads\Downloads_1\Nagaraj_Anna\new_folder\ALL_CORPORA-TO-EDIT-xlsx_format_new.xlsm")

# we are reading our file which is in the xlsx format as a pandas dataframe

# %%
data.columns = ['Text']

# we are assigning the column name as 'Text'

# %%
data[:]

# we are visualizing the dataframe from first to last terms
# Out:
#                                                     Text
# 0      QT_QTC RD_SYM N_NN V_VM_VNF N_NST N_NN PR_PRP ...
# 1      N_NN N_NN V_VM_VNF N_NN PR_PRQ V_VM_VNF V_VAUX...
# 2      QT_QTC RD_SYM N_NN N_NN RD_PUNC N_NN N_NN RD_P...
# 3      QT_QTC RD_SYM N_NN JJ N_NN V_VM_VNF N_NN PR_PR...
# 4      DM_DMD N_NN DM_DMD N_NN V_VM_VINF N_NN N_NN PR...
# ...                                                  ...
# 10380                             JJ PR_PRP N_NN RD_PUNC
# 10381  N_NN N_NN V_VM_VNF N_NN RD_PUNC N_NN N_NN V_VM...
# 10382                   RB V_VM_VNF N_NN V_VM_VF RD_PUNC
# 10383                                            RD_PUNC
# 10384                                             QT_QTC
#
# [10385 rows x 1 columns]

# %%
list_strings = data['Text'].values.tolist()

# we are converting our text column into a list with each values as a string
# Each sentence in our corpus will be converted into a string of tags and all such string of tags will be stored in a list
# look at the format of list_strings below

# %%
list_strings
# Out:
# ['QT_QTC RD_SYM N_NN V_VM_VNF N_NST N_NN PR_PRP V_VM_VINF N_NN N_NN V_VM_VNF N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN PR_PRQ V_VM_VNF V_VAUX PR_PRP N_NN QT_QTF N_NN V_VM_VFRD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN V_VM_VNF N_NN N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN JJ N_NN V_VM_VNF N_NN PR_PRQ N_NN N_NN N_NN V_VM_VNF PR_PRP N_NN QT_QTF V_VM_VF RD_PUNC',
#  'DM_DMD N_NN DM_DMD N_NN V_VM_VINF N_NN N_NN PR_PRP V_VM_VINF N_NN N_NN JJ N_NN N_NN V_VM_VINF JJ N_NN N_NN N_NN JJ N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_SYM N_NST V_VM_VINF N_NN V_VM_VNF N_NNP N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN QT_QTF N_NN CC_CCD N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VINF N_NN N_NN RP_RPD N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN N_NN N_NN QT_QTF N_NN V_VM_VINF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG JJ N_NN N_NN DM_DMD N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG JJ N_NN N_NN N_NN RB V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN N_NN N_NN N_NN N_NN N_NN PSP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN N_NN RP_RPD QT_QTC N_NN V_VM_VNG RP_RPD RP_INTF N_NN RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN JJ N_NN N_NN N_NN N_NN RP_RPD N_NN QT_QTC N_NN V_VM_VNF N_NN RP_INTF N_NN RD_PUNC',
#  'N_NNP N_NN N_NN RD_PUNC N_NN RD_PUNC N_NN QT_QTF N_NN V_VM_VNF RD_PUNC',
#  'DM_DMD N_NN PR_PRP V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN RD_PUNC RB RB N_NN N_NN V_VM_VNF N_NN V_VAUX RD_PUNC',
#  'PR_PRP QT_QTC N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN PSP RP_RPD N_NN PR_PRP PR_PRP N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG JJ N_NN N_NN N_NN PR_PRP N_NN V_VM_VINF N_NN PSP V_VM_VF RD_PUNC',
#  'PSP N_NN N_NN PSP PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN RD_PUNC N_NN N_NN N_NST V_VM_VINF N_NN V_VM_VNF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_SYM DM_DMR RD_SYM N_NN N_NN RD_SYM N_NN RD_SYM N_NN N_NN N_NN RD_SYM N_NN RD_SYM N_NN N_NN RD_SYM N_NN RD_SYM N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN N_NN QT_QTF N_NN N_NN PSP RD_PUNC PR_PRP N_NN N_NN JJ N_NN N_NN PSP RD_PUNC N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTF JJ N_NN V_VM_VNF QT_QTF JJ N_NN V_VM_VF RD_PUNC',
#  'RB QT_QTF N_NN N_NN RP_RPD RB V_VM_VF RD_PUNC',
#  'PR_PRP PSP N_NNP N_NN N_NN N_NN QT_QTC PSP QT_QTC PSP DM_DMD N_NN N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMQ JJ N_NN N_NN JJ N_NN N_NN QT_QTF JJ N_NN RD_PUNC',
#  'CC_CCS N_NN V_VM_VNF N_NN QT_QTF V_VM_VF RD_PUNC',
#  'QT_QTF N_NN V_VM_VNF JJ N_NN N_NN RD_PUNC',
#  'QT_QTC QT_QTC JJ N_NN N_NN RP_RPD PR_PRP N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST DM_DMD N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC JJ N_NN V_VM_VINF N_NN V_VM_VNF PSP N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC JJ N_NN N_NN N_NN N_NN N_NST V_VM_VINF N_NN V_VM_VINF N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC DM_DMR N_NN QT_QTC N_NN V_VM_VNF RD_PUNC DM_DMD N_NN N_NN QT_QTC V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN V_VM_VINF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN JJ N_NN N_NN N_NN N_NN V_VM_VINF N_NN RD_PUNC N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN RD_PUNC DM_DMD N_NN V_VM_VINF N_NN V_VM_VINF N_NN V_VM_VNF RD_PUNC DM_DMD N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN V_VM_VINF N_NN N_NN N_NN RB V_VM_VF RD_PUNC N_NN N_NN V_VM_VNF N_NST RD_PUNC N_NST RD_PUNC N_NN N_NN PR_PRP PSP RB V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN V_VM_VNF N_NN CC_CCD N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN RD_PUNC QT_QTC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN V_VM_VNF N_NN QT_QTC N_NN JJ V_VM_VNF JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC JJ N_NN N_NN N_NN RP_RPD QT_QTF N_NST N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD JJ N_NN N_NST N_NN RD_PUNC',
#  'N_NN RD_SYM N_NN N_NN V_VM_VNF V_VM_VINF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_SYM QT_QTF N_NN N_NN V_VM_VINF N_NN QT_QTC RD_SYM RP_RPD N_NN CC_CCD N_NN V_VM_VNF N_NN N_NN QT_QTC RD_SYM V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC QT_QTC RD_PUNC QT_QTC N_NN N_NN N_NN N_NN V_VM_VNF JJ N_NN N_NN N_NN N_NN RD_PUNC N_NN RD_PUNC N_NST RB V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN N_NN JJ N_NN N_NN N_NN PSP V_VM_VF RD_PUNC',
#  'N_NN N_NST CC_CCD RD_PUNC CC_CCD N_NN V_VM_VNF CC_CCD RD_PUNC PR_PRP N_NN N_NN N_NN PSP V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NST V_VM_VNF N_NST RD_PUNC RB RP_INTF RB N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN RD_PUNC QT_QTF RD_PUNC N_NN N_NN RD_PUNC CC_CCS_UT V_VM_VINF QT_QTC RD_PUNC DM_DMD N_NN V_VM_VNG N_NN V_VM_VINF N_NN RD_PUNC N_NN N_NN N_NN N_NN RD_SYM N_NN N_NN N_NN N_NN RD_SYM RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VINF N_NN PSP N_NN V_VM_VF RD_PUNC',
#  'CC_CCD RD_PUNC N_NN RD_PUNC QT_QTC N_NN QT_QTF RP_CL N_NN V_VM_VNF N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMD RB V_VM_VINF N_NN PSP RD_PUNC',
#  'DM_DMD N_NN QT_QTC N_NN N_NN V_VM_VNF N_NN QT_QTC N_NN DM_DMD N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VNF N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC',
#  'PR_PRP QT_QTC N_NST N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN DM_DMQ QT_QTC N_NN V_VM_VNF PR_PRP N_NN JJ N_NN N_NN RD_PUNC RB V_VM_VNF QT_QTC N_NN RP_RPD N_NN N_NN V_VM_VF RD_PUNC',
#  'RB DM_DMD N_NN JJ N_NN N_NN V_VM_VNF N_NN RP_RPD PR_PRP V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN PSP RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VINF V_VAUX RD_PUNC',
#  'N_NN N_NN N_NN RD_SYM RD_PUNC',
#  'PR_PRP V_VM_VNF N_NN V_VM_VNF RD_PUNC DM_DMD N_NN RP_RPD RB V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN V_VM_VINF N_NN RP_RPD V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN N_NN N_NN N_NN N_NN N_NN N_NN RD_SYM RD_PUNC',
#  'N_NN V_VM_VNF N_NN QT_QTF N_NN N_NN RB N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN DM_DMQ CC_CCS RD_PUNC',
#  'QT_QTC RD_SYM N_NN QT_QTC JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM JJ N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC N_NN RD_PUNC N_NN RB V_VM_VF RD_PUNC',
#  'RD_SYM QT_QTC RD_SYM N_NN V_VM_VINF N_NST N_NN N_NN RP_NEG CC_CCD N_NN N_NN V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN V_VM_VNG RP_RPD N_NN N_NN V_VM_VINF N_NN N_NN RD_PUNC N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN DM_DMR JJ N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN DM_DMQ RB PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN V_VM_VNF N_NN JJ N_NN N_NN RD_PUNC JJ N_NN N_NN N_NN N_NN N_NN N_NN N_NN RB N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN V_VM_VINF N_NST N_NN N_NN V_VM_VNF RP_RPD RB PR_PRP V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMD N_NN JJ N_NN N_NST V_VM_VNF QT_QTF N_NN N_NN V_VM_VNG PSP DM_DMR N_NN V_VM_VF RD_PUNC',
#  'N_NN RP_NEG RD_PUNC N_NN N_NN RP_NEG V_VM_VINF N_NN V_VM_VNG PSP N_NN N_NN V_VM_VNF N_NN DM_DMD N_NN RP_RPD RB V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'CC_CCD N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VNF RD_PUNC',
#  'DM_DMD N_NN V_VM_VINF N_NN RB V_VM_VINF N_NN PR_PRP V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMR QT_QTC N_NN QT_QTF N_NN V_VM_VINF N_NN PSP JJ N_NN N_NN PSP V_VM_VF RD_SYM N_NNP N_NN N_NN N_NN RD_SYM RD_PUNC',
#  'N_NN RD_PUNC N_NN V_VM_VINF N_NN N_NN RB V_VM_VNF DM_DMD N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN N_NN RP_RPD DM_DMD N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'V_VM_VNF DM_DMR N_NN RP_RPD N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'RP_RPD V_VM_VINF PR_PRP V_VM_VF RD_PUNC',
#  'QT_QTF RP_RPD N_NN N_NN PR_PRP RB N_NN N_NN CC_CCS_UT V_VM_VNF V_VAUX V_VM_VF N_NN V_VM_VNF JJ N_NN N_NN RD_PUNC',
#  'N_NN N_NN V_VM_VNF DM_DMR N_NN V_VM_VINF N_NN RP_NEG RD_PUNC',
#  'PR_PRP N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN N_NN RD_SYM N_NN DM_DMQ V_VM_VF RD_PUNC RB N_NN N_NN JJ N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VINF N_NN RP_INTF N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NNP N_NN N_NN N_NN QT_QTC N_NN V_VM_VINF N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN JJ N_NN N_NN V_VM_VNF RP_RPD N_NN N_NN RB V_VM_VINF QT_QTC RP_CL N_NN RD_PUNC N_NN N_NN RB JJ N_NN QT_QTC N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VINF N_NN PSP QT_QTC N_NST N_NN V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VINF N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF DM_DMD N_NN V_VM_VNF N_NN PR_PRP N_NN PR_PRP N_NN PR_PRP N_NN RD_PUNC N_NN V_VM_VINF N_NN N_NN RB N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RB N_NN V_VM_VINF N_NN RP_RPD N_NN N_NN PSP RD_PUNC QT_QTC N_NN N_NN N_NN CC_CCD JJ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN JJ N_NN RB V_VM_VNF N_NST V_VM_VINF N_NN QT_QTF N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMR RB N_NN N_NN V_VM_VNF N_NN JJ N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN PSP DM_DMQ N_NN V_VM_VNF N_NN N_NN N_NN PSP V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTF N_NN N_NN N_NN V_VM_VNF RB JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN PSP V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN V_VM_VNF V_VAUX RP_RPD N_NN RB V_VM_VF RD_PUNC',
#  'CC_CCS N_NN V_VM_VNF N_NN RB V_VM_VF RD_PUNC',
#  'N_NNP CC_CCD N_NN N_NN N_NNP CC_CCD N_NN RD_SYM RP_RPD N_NN V_VM_VNF N_NN N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN DM_DMQ V_VM_VNF N_NN N_NN N_NN N_NN QT_QTC PSP V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN N_NN CC_CCD N_NN N_NN RD_PUNC DM_DMR JJ N_NN N_NN N_NNP N_NN QT_QTC N_NN RD_PUNC',
#  'N_NN CC_CCS N_NN V_VM_VNF N_NN N_NN CC_CCS_UT V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN CC_CCD V_VM_VNF N_NN N_NN PR_PRP N_NN V_VM_VNF DM_DMD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN N_NN PR_PRP N_NN PSP JJ N_NN N_NN RB V_VM_VNG DM_DMQ N_NN RD_PUNC',
#  'DM_DMR N_NN N_NST DM_DMR N_NN N_NN V_VM_VNF CC_CCD N_NN RP_RPD N_NN V_VM_VNF N_NN N_NN V_VM_VNF RD_PUNC',
#  'N_NN N_NN QT_QTC N_NN V_VM_VINF RD_PUNC N_NN N_NN QT_QTF N_NN V_VM_VNF N_NN N_NN N_NN RP_INTF N_NN RD_PUNC',
#  'V_VM_VINF N_NN V_VAUX RD_PUNC N_NST V_VM_VNF N_NN N_NN V_VM_VINF RP_RPD N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC DM_DMD N_NN N_NN RP_RPD V_VM_VNG RB V_VM_VF RD_PUNC',
#  'N_NST N_NN CC_CCD N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP QT_QTC N_NN RB V_VM_VNF N_NN RD_PUNC',
#  'N_NN JJ N_NN N_NN N_NN RB V_VM_VNF N_NN RD_PUNC',
#  'DM_DMR QT_QTC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN RB V_VM_VNF DM_DMD N_NN V_VM_VNF N_NN N_NN V_VM_VNF N_NST QT_QTC RD_PUNC QT_QTC N_NN V_VM_VNF N_NN N_NN PR_PRP V_VM_VF RD_PUNC',
#  'N_NN N_NST V_VM_VNG PSP PR_PRP V_VM_VNF DM_DMR N_NN RP_RPD N_NST N_NN RD_PUNC N_NST N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNG N_NN N_NN JJ N_NN N_NN QT_QTC RD_PUNC',
#  'RB N_NN N_NN N_NN V_VM_VINF N_NST N_NN N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'QT_QTC PR_PRP N_NST QT_QTC N_NN V_VAUX N_NN N_NN RD_PUNC N_NN JJ N_NN V_VM_VNF V_VM_VNF RB N_NN V_VM_VF N_NN N_NN V_VM_VNF N_NST QT_QTC N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM DM_DMQ N_NN DM_DMD N_NN V_VM_VNF V_VM_VF QT_QTC RD_SYM PR_PRP DM_DMR N_NN V_VM_VNG N_NN RD_PUNC',
#  'DM_DMQ QT_QTC N_NN N_NN N_NN N_NST RB V_VM_VNF N_NN RB V_VM_VNG N_NN RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNG RD_PUNC JJ N_NN N_NN N_NN V_VM_VNG RD_PUNC N_NN RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN JJ N_NN N_NN N_NST N_NN V_VM_VNG N_NN RD_PUNC JJ N_NN N_NN RD_PUNC JJ N_NN N_NN V_VM_VNF N_NN N_NN N_NST V_VM_VNG N_NN N_NN RD_PUNC',
#  'PR_PRP PSP N_NN N_NN V_VAUX N_NN RB V_VM_VNF V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC N_NN N_NN N_NN N_NN RP_INTF N_NN RB V_VM_VNF V_VM_VINF N_NN N_NST N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC N_NN V_VM_VINF N_NN RD_PUNC N_NN N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VINF N_NN N_NN N_NN RD_PUNC N_NN N_NST V_VM_VNF V_VM_VNG N_NN RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN RD_PUNC N_NN QT_QTC RB N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN RB RB N_NN N_NN RD_PUNC',
#  'N_NN RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN V_VM_VNGRD_PUNC',
#  'QT_QTC RD_SYM N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN N_NN V_VM_VNG RD_PUNC',
#  'N_NST V_VM_VINF RB V_VAUX JJ N_NN N_NN PSP N_NN V_VM_VNF N_NN V_VM_VNF N_NN RP_RPD QT_QTF V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN PSP N_NN N_NN V_VM_VNF N_NN N_NN RP_RPD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_SYM DM_DMR N_NN N_NN N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VNF V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NNP N_NN QT_QTO N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VNF V_VM_VNG RD_PUNC PR_PRP V_VM_VNF N_NN N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM PR_PRP N_NN N_NN N_NN QT_QTC PSP QT_QTC PSP V_VM_VNG',
#  'QT_QTC RD_SYM N_NN V_VM_VINF RB N_NN N_NN N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN QT_QTC N_NN V_VM_VNF N_NN N_NN V_VM_VINF N_NN V_VM_VNG RD_PUNC PR_PRP N_NN N_NN V_VM_VNG RD_PUNC',
#  'DM_DMR QT_QTO N_NN N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VNG N_NN RB V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN PSP RP_RPD N_NN N_NN QT_QTF N_NN N_NN RP_RPD V_VM_VF RD_PUNC',
#  'V_VM_VINF N_NN N_NN RD_PUNC DM_DMD N_NN V_VM_VINF PR_PRP N_NN RD_PUNC PR_PRP V_VM_VNF PR_PRP N_NN N_NN N_NN PSP DM_DMD N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN N_NN N_NN N_NN QT_QTF V_VM_VNF N_NN N_NN RD_PUNC V_VM_VINF N_NN N_NN V_VM_VINF N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN QT_QTC N_NN QT_QTC N_NN V_VM_VINF N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC V_VM_VF RD_PUNC',
#  'V_VM_VNG RD_PUNC PR_PRP V_VM_VNG RD_PUNC',
#  'N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RB N_NN V_VM_VINF N_NN N_NN V_VM_VF RD_PUNC',
#  'RP_RPD QT_QTF N_NN N_NN N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN N_NN RD_PUNC PR_PRP N_NN N_NN JJ N_NN RB N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RB N_NN RP_RPD PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST DM_DMD N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG PSP N_NN V_VM_VNF RP_RPD V_VM_VF RD_PUNC',
#  'N_NN PSP N_NN V_VM_VNF RD_PUNC DM_DMD N_NN N_NN V_VM_VINF N_NN PSP RB N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD JJ N_NN QT_QTF RP_CL N_NN N_NN N_NN JJ N_NN QT_QTC N_NN V_VM_VINF N_NST N_NN N_NN CC_CCD V_VM_VINF N_NN V_VAUX N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NNP N_NN N_NN N_NN N_NN V_VM_VNF N_NN RB N_NN RD_SYM JJ N_NN N_NN RD_SYM CC_CCD N_NN RP_RPD V_VM_VF RD_PUNC _',
#  'N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTF RP_CL N_NN N_NN N_NN N_NN RB N_NN V_VAUX RD_PUNC',
#  'N_NN RB V_VAUX N_NN N_NN RB V_VM_VNG V_VM_VNF V_VM_VINF RD_PUNC PR_PRP N_NN N_NN V_VM_VNF PR_PRP N_NN DM_DMR N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RP_RPD DM_DMR JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN N_NN N_NN N_NN RP_RPD RP_RPD RB N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF JJ N_NN N_NN RD_PUNC',
#  'PR_PRP V_VM_VINF N_NN RD_PUNC N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NST N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RP_NEG RB V_VM_VNF N_NN V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN RB DM_DMR N_NST RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN V_VM_VNF PR_PRP V_VM_VNF V_VM_VNG RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RD_PUNC',
#  'N_NNP RD_PUNC JJ N_NN N_NN RB QT_QTC N_NN V_VM_VNG N_NN RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN RD_PUNC',
#  'RB N_NN RB V_VM_VINF N_NN N_NN N_NN RD_PUNC N_NN N_NN RB V_VM_VNG N_NN RD_PUNC',
#  'RP_RPD QT_QTF N_NN N_NN N_NN N_NN RB V_VM_VINF N_NN DM_DMQ N_NN N_NN N_NN RB V_VM_VNG V_VAUX RD_PUNC',
#  'N_NN N_NN RP_INTF N_NN RD_PUNC',
#  'RP_INTF N_NN RD_PUNC',
#  'N_NN V_VM_VF RD_PUNC RB V_VM_VINF N_NN RB PR_PRP V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VNG PR_PRP N_NN N_NST RD_PUNC',
#  'N_NN N_NST RD_PUNC N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'JJ N_NN N_NN N_NN N_NN N_NN V_VM_VF N_NN V_VM_VF RD_PUNC DM_DMQ N_NN V_VM_VNF N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN PR_PRP V_VM_VINF N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VNF QT_QTF N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RB N_NN V_VM_VNF PR_PRP N_NN N_NN RD_PUNC',
#  'RB V_VM_VF RD_PUNC',
#  'CC_CCD N_NN RB V_VM_VNF N_NN N_NN DM_DMR RP_RPD V_VM_VF QT_QTF N_NN PR_PRP N_NN V_VM_VF N_NN N_NN RD_PUNC',
#  'JJ N_NN N_NN N_NN V_VM_VNF N_NN QT_QTC N_NN PR_PRP V_VM_VF RD_PUNC N_NNP N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN RD_PUNC N_NN V_VM_VNF N_NN RB V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN CC_CCS DM_DMQ V_VM_VF RD_PUNC',
#  'N_NN RB N_NN V_VM_VNG RP_RPD QT_QTC N_NN RD_PUNC',
#  'N_NN N_NN N_NN PSP RD_PUNC N_NN PSP QT_QTC RD_PUNC V_VM_VNF N_NN PSP N_NN RP_RPD N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_INTF N_NN RD_PUNC',
#  'PR_PRP CC_CCD N_NN N_NN RD_PUNC',
#  'N_NN N_NN PSP N_NN N_NN N_NN RD_PUNC N_NN N_NN RP_RPD N_NN N_NN RD_PUNC',
#  'RB V_VM_VNF N_NN N_NN N_NN RB V_VM_VNF V_VM_VNF N_NN V_VM_VNF PR_PRP N_NN N_NN RP_RPD N_NN V_VM_VNF RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC RD_PUNC JJ N_NN N_NN N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN RD_PUNC N_NNP QT_QTC N_NN N_NN N_NN V_VM_VNF N_NN N_NN N_NN RD_PUNC',
#  'QT_QTF N_NN PR_PRP N_NN RB N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN DM_DMQ V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC RD_PUNC RB V_VM_VNF N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN RD_PUNC',
#  'RB V_VM_VINF RB V_VM_VF RD_PUNC',
#  'RB V_VM_VNF RD_PUNC JJ N_NN N_NN N_NN N_NN V_VM_VNF N_NN JJ N_NN N_NN RP_RPD PR_PRP N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NST N_NN N_NN N_NN RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN PR_PRP V_VM_VINF N_NN PSP RP_INTF V_VM_VNF RD_PUNC N_NNP RD_PUNC N_NNP RD_PUNC V_VM_VNG V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC RD_PUNC JJ N_NN N_NN N_NN JJ N_NN N_NN QT_QTF N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'RB JJ N_NN N_NN N_NN N_NN PSP RD_PUNC PR_PRP V_VM_VINF N_NN N_NN PSP JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP V_VM_VNF N_NN N_NN N_NN PSP V_VM_VNF N_NN N_NN RD_PUNC',
#  'V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN PSP JJ N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP N_NN RD_PUNC RD_PUNC N_NN N_NN V_VM_VNG N_NN RB N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC',
#  'PR_PRP N_NN N_NN RD_PUNC N_NN RB V_VM_VNF DM_DMQ V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN PR_PRP V_VM_VNF RB RB PR_PRP N_NN V_VM_VF RD_PUNC',
#  'RB N_NN N_NN N_NN RB V_VM_VNF RB QT_QTF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC RD_PUNC RB V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VNG V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN N_NN N_NN DM_DMQ V_VM_VNF RD_PUNC N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN DM_DMQ N_NN RD_PUNC',
#  'RD_PUNC N_NNP RD_PUNC QT_QTC RD_PUNC RB V_VM_VNF N_NN N_NN N_NN N_NN RD_PUNC',
#  'N_NN N_NN V_VM_VNF RD_PUNC CC_CCD JJ N_NN N_NN V_VM_VNF N_NN RD_PUNC N_NN N_NN V_VM_VNF N_NN JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF RP_RPD N_NN N_NN V_VM_VNF N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN JJ N_NN JJ N_NN RD_PUNC N_NN V_VM_VNF V_VM_VNF RB V_VM_VF RD_PUNC',
#  'RD_PUNC N_NNP RD_PUNC QT_QTC RD_PUNC RD_PUNC N_NN N_NN N_NN N_NN DM_DMQ N_NN RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VINF N_NN QT_QTC N_NN PSP CC_CCD JJ N_NN N_NN PSP N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN N_NN N_NN DM_DMQ N_NN N_NN RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN RP_RPD N_NN RP_INTF N_NN RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN N_NN JJ N_NN N_NN RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN PSP PR_PRP V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN CC_CCD N_NN N_NN N_NN N_NN PSP DM_DMR RB V_VM_VF RD_PUNC',
#  'RD_PUNC N_NN N_NN DM_DMQ RB N_NN V_VM_VF RD_PUNC',
#  'QT_QTF RP_CL N_NN N_NN RD_PUNC QT_QTC N_NN N_NN N_NN V_VM_VNF DM_DMD N_NN PSP N_NN N_NN N_NN PSP PR_PRP PSP V_VM_VF RD_PUNC',
#  'PR_PRP RB N_NN V_VM_VNF N_NN PR_PRP PR_PRP V_VM_VF RD_PUNC',
#  'PR_PRP JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN PSP PR_PRP N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'RD_PUNC N_NN N_NN DM_DMR N_NST RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN QT_QTC N_NN N_NN V_VM_VNG N_NN N_NN JJ N_NN RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NNP RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD N_NN N_NN V_VM_VNF N_NN N_NN N_NN RD_PUNC',
#  'PR_PRP N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN QT_QTF RP_CL N_NN V_VM_VNF RB V_VM_VNF PR_PRP V_VM_VNF RB V_VM_VNF RD_PUNC CC_CCD PR_PRP PR_PRP N_NN PR_PRP N_NN PR_PRP N_NN PSP N_NST RP_RPD V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN V_VM_VINF N_NN DM_DMQ V_VM_VF RD_PUNC',
#  'N_NN PR_PRP N_NN JJ N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RB V_VM_VINF N_NN N_NN N_NN N_NN V_VM_VNF CC_CCD N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RB RB RB N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN N_NN RD_PUNC N_NN N_NN QT_QTC RD_PUNC N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMQ N_NN N_NN V_VM_VNF N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN RB QT_QTC N_NN N_NN RD_PUNC',
#  'PR_PRP N_NN RP_RPD RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN RB V_VM_VNF N_NN N_NN RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN V_VM_VNF N_NN N_NN RD_PUNC JJ N_NN V_VM_VINF PR_PRP RD_PUNC N_NN N_NN N_NN PR_PRP N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN JJ N_NN N_NN N_NN N_NN V_VM_VNF N_NN N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM RB V_VM_VNF N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'RP_RPD N_NN N_NN V_VM_VNF N_NN N_NN N_NN PSP N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN QT_QTF QT_QTC N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN RB V_VM_VF RD_PUNC',
#  'RB V_VM_VINF N_NN N_NN N_NN N_NN RB V_VM_VNF N_NN N_NN V_VM_VNF RD_SYM N_NNP N_NN N_NN RD_SYM RD_PUNC',
#  'QT_QTC RD_SYM N_NN V_VM_VINF N_NN RD_PUNC N_NNP RD_PUNC N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD RB V_VM_VNF N_NN N_NN N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN RB RB V_VM_VF RD_PUNC',
#  'N_NN PR_PRP N_NN V_VM_VNF N_NN V_VM_VINF N_NN N_NN RD_PUNC',
#  'V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'PR_PRP RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RB V_VM_VNG V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN JJ N_NN N_NN V_VM_VINF N_NN RB V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF N_NN RP_RPD V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN N_NN N_NN PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN RB V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMR N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG PR_PRP JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN PR_PRP JJ N_NN N_NN V_VM_VNF PR_PRP V_VM_VNF V_VAUX RD_PUNC',
#  'PR_PRP N_NN N_NNP N_NN N_NN RD_SYM RD_PUNC',
#  'QT_QTC RD_SYM N_NN N_NN V_VM_VNG N_NN N_NN QT_QTC RD_PUNC',
#  'DM_DMQ QT_QTC N_NN JJ N_NN N_NN N_NN CC_CCD JJ N_NN RB V_VM_VNF CC_CCD N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NST N_NN N_NN N_NST V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN N_NN N_NN CC_CCD N_NN RD_PUNC N_NN CC_CCD N_NN N_NN N_NN V_VM_VNG N_NN V_VM_VF RD_PUNC',
#  'RP_RPD QT_QTC N_NN QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN QT_QTC N_NN V_VM_VNF QT_QTF N_NN N_NN V_VM_VINF PR_PRP N_NN CC_CCS V_VM_VF RD_PUNC',
#  'CC_CCS N_NN RD_PUNC N_NN PSP RP_NEG N_NN N_NST V_VM_VINF N_NN V_VM_VNF CC_CCS V_VM_VNF N_NN DM_DMD N_NN RB V_VM_VF RD_PUNC',
#  'CC_CCD PR_PRP N_NN PR_PRP QT_QTF N_NN RD_PUNC N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'QT_QTC N_NN N_NN CC_CCD QT_QTF N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMR RB V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN RP_RPD JJ N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF JJ N_NN N_NN N_NN RP_RPD N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_PUNC DM_DMR N_NN CC_CCD PR_PRP N_NN N_NN V_VM_VNF PSP V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD N_NN N_NN N_NN RP_RPD DM_DMR JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC DM_DMQ QT_QTC N_NN QT_QTC N_NN N_NN N_NN V_VM_VNF RB N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NN PR_PRP N_NST N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN N_NN N_NN N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_PUNC RB N_NN N_NN N_NN RD_PUNC RB V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RB V_VM_VNF DM_DMR JJ N_NN N_NN N_NN N_NN V_VM_VINF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF PR_PRP RB N_NN N_NN V_VM_VF RD_PUNC',
#  'CC_CCS N_NN N_NN V_VM_VNF V_VM_VINF N_NN CC_CCD V_VM_VINF N_NN DM_DMD N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTF N_NN PSP N_NN N_NN N_NN PR_PRP N_NN RP_RPD V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN DM_DMQ QT_QTC N_NN N_NN V_VM_VNF N_NST N_NN V_VM_VNF N_NN N_NN N_NN DM_DMR N_NN DM_DMD N_NN V_VM_VINF N_NN QT_QTF N_NN RD_PUNC',
#  'N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF QT_QTF N_NN DM_DMR N_NST RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN PSP N_NN QT_QTF N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN PSP N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN PSP N_NN V_VM_VINF QT_QTF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN QT_QTF N_NN N_NN CC_CCD N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NN N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VNF V_VM_VNF RB V_VM_VNF',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF CC_CCD N_NN N_NN PR_PRP N_NN RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN PSP N_NN N_NST V_VM_VINF N_NN CC_CCD PR_PRP N_NN DM_DMR N_NN V_VM_VNF N_NN RP_RPD N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN N_NN N_NN RP_RPD V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RB RD_PUNC N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC PR_PRP N_NN N_NST N_NN V_VM_VINF N_NN PSP JJ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN DM_DMQ N_NN V_VM_VNF JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'RP_RPD N_NN V_VM_VNF QT_QTC N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN DM_DMQ N_NN RB V_VM_VF RD_PUNC',
#  'RB V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN DM_DMQ N_NN N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_PUNC N_NN DM_DMQ N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'RP_RPD N_NN N_NN N_NN CC_CCD N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN V_VM_VINF N_NST RP_RPD N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN RP_INTF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN CC_CCD N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMR N_NN JJ N_NN N_NN RP_RPD V_VM_VINF N_NN PR_PRP V_VM_VINF N_NN RP_RPD V_VM_VNF',
#  'QT_QTC RD_PUNC QT_QTC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP PR_PRP JJ N_NN N_NN PR_PRP N_NN N_NN RP_RPD RB N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VNF RB PR_PRP V_VM_VF RD_PUNC',
#  'RP_RPD PR_PRP V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNG N_NN V_VM_VINF N_NN N_NN N_NN QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VINF N_NST PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN RB N_NN N_NN PR_PRP N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC',
#  'DM_DMR N_NN RP_RPD N_NN DM_DMQ V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN RP_RPD PR_PRP N_NN RP_RPD N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG N_NN N_NN N_NN QT_QTC RD_PUNC',
#  'PR_PRP N_NN JJ N_NN N_NN RP_RPD N_NN V_VM_VNF PR_PRP N_NN N_NN V_VM_VNG N_NN QT_QTF N_NN N_NN V_VM_VNF PR_PRP N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NST N_NN DM_DMQ V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN',
#  'QT_QTC RD_PUNC N_NN',
#  'QT_QTC RD_PUNC N_NNP',
#  'QT_QTC RD_PUNC N_NN N_NN',
#  'QT_QTC RD_PUNC N_NN',
#  'QT_QTC RD_PUNC V_VM_VNG',
#  'QT_QTC RD_PUNC V_VM_VNG',
#  'QT_QTC RD_PUNC N_NN N_NN N_NST V_VM_VINF N_NN N_NN N_NN V_VM_VINF N_NN RD_PUNC DM_DMD N_NN V_VM_VNF RD_PUNC N_NN RD_PUNC N_NN N_NN V_VM_VINF N_NN PSP RD_PUNC N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VINF N_NN N_NN QT_QTC PSP N_NN QT_QTC PSP V_VM_VNF V_VAUX RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN RB N_NN V_VM_VF RD_PUNC',
#  'RB V_VM_VINF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF RP_INTF RB N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC',
#  'N_NN N_NN N_NN N_NN RD_PUNC JJ N_NN N_NN V_VM_VNF V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN N_NN QT_QTC RD_PUNC',
#  'N_NN RD_PUNC QT_QTC N_NN V_VM_VNF N_NN DM_DMQ QT_QTC N_NN PR_PRP N_NN N_NN N_NN RD_PUNC CC_CCD N_NN N_NN V_VM_VNF DM_DMD N_NN N_NN CC_CCS V_VM_VF RD_PUNC',
#  'DM_DMQ QT_QTC N_NN N_NST N_NN RB V_VM_VNF V_VM_VNF DM_DMR N_NN PSP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RB N_NN N_NN PR_PRP N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMQ QT_QTC N_NN N_NN RB V_VM_VNF RP_NEG CC_CCD PR_PRP N_NN N_NN V_VM_VNF RD_PUNC PR_PRP N_NN PSP RB V_VM_VF RD_PUNC',
#  'RP_RPD RD_PUNC N_NN N_NN RB V_VM_VINF N_NN RD_PUNC CC_CCD PR_PRP N_NN RP_RPD JJ N_NN N_NN N_NN DM_DMR N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NST N_NN V_VM_VNF N_NN V_VM_VINF N_NN PR_PRP N_NN RB N_NN V_VM_VNG N_NN RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN DM_DMQ QT_QTC N_NN N_NN V_VM_VNF RD_PUNC DM_DMR N_NN RB V_VM_VINF PR_PRP RD_PUNC V_VM_VNF RD_PUNC CC_CCS V_VM_VNF RD_PUNC CC_CCS V_VM_VNF DM_DMD N_NN V_VM_VNF N_NN RB RD_PUNC N_NN RB N_NN V_VM_VNF RD_PUNC V_VM_VNF RD_PUNC CC_CCS V_VM_VNF V_VM_VNF RD_PUNC PR_PRP N_NN PR_PRP RD_PUNC V_VM_VNF RD_PUNC CC_CCS N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN RD_PUNC V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF RD_PUNC V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF RB V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD DM_DMQ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NN V_VM_VNF V_VM_VNF DM_DMR N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD DM_DMD N_NN N_NN N_NN V_VM_VNF N_NN DM_DMR N_NN N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'RP_INTF N_NN N_NN DM_DMR N_NN CC_CCD N_NN N_NN RB RD_PUNC RB V_VM_VNF DM_DMR N_NN N_NN RP_INTF N_NN DM_DMR RD_PUNC N_NN N_NN RD_PUNC PR_PRP V_VM_VNG V_VAUX RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VINF N_NN DM_DMR N_NN N_NST RB N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VNF DM_DMD N_NN DM_DMR N_NN RB V_VM_VNF N_NN PR_PRP V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC V_VM_VNF V_VM_VNF PR_PRP N_NN V_VM_VNG RD_PUNC DM_DMR N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC',
#  'DM_DMQ N_NN N_NN N_NN V_VM_VNF RD_PUNC V_VM_VNF N_NN RP_RPD RD_PUNC N_NN N_NN V_VM_VINF PR_PRP N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN V_VM_VINF N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN DM_DMD N_NN N_NN PSP DM_DMD N_NN V_VM_VNF RD_PUNC PR_PRP V_VM_VF RD_PUNC',
#  'DM_DMR N_NN V_VM_VNF N_NN PSP RB V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN DM_DMR N_NN QT_QTF RB V_VM_VF RD_PUNC',
#  'N_NST V_VM_VNF DM_DMR N_NN N_NN N_NN RB V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN RB V_VM_VNF V_VM_VF RD_PUNC',
#  'RP_RPD V_VM_VNF DM_DMR N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'RD_PUNC N_NNP RD_PUNC QT_QTC RD_PUNC RD_PUNC N_NN V_VM_VNF RP_RPD N_NN N_NN N_NN V_VM_VNF N_NN N_NN RD_PUNC',
#  'N_NST N_NN DM_DMQ QT_QTC N_NN V_VM_VNF PR_PRP QT_QTC N_NN RD_PUNC DM_DMD N_NN V_VM_VNF PR_PRP N_NN N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMD RB N_NN QT_QTC N_NN V_VM_VINF N_NN N_NN PR_PRP RB V_VM_VF RD_PUNC',
#  'DM_DMD N_NN QT_QTC N_NN V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN N_NN PSP N_NN V_VM_VNF RD_PUNC PR_PRP V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN PR_PRP N_NN N_NN N_NN V_VM_VNF RD_PUNC DM_DMD N_NN V_VM_VNF CC_CCD PR_PRP V_VM_VF RD_PUNC',
#  'DM_DMR N_NN RB N_NN N_NN RD_PUNC N_NN N_NN RB V_VM_VNG N_NN RD_PUNC',
#  'PR_PRP N_NN N_NN RB N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF PR_PRP RD_PUNC V_VM_VNF PR_PRP RB N_NST V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD DM_DMR N_NN N_NN RP_RPD QT_QTF V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD RP_INTF N_NN V_VM_VF RD_PUNC',
#  'N_NN PSP V_VM_VINF N_NN RD_PUNC',
#  'N_NN N_NN QT_QTF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMR N_NN DM_DMR N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RD_PUNC N_NN N_NN N_NN N_NN PSP V_VM_VINF N_NN N_NN N_NN QT_QTC RD_PUNC',
#  'N_NN CC_CCS N_NN V_VM_VNF V_VM_VNF N_NN DM_DMR N_NN N_NN CC_CCD N_NN N_NN N_NN N_NN V_VM_VINF JJ N_NN N_NN N_NN CC_CCD QT_QTC N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN PSP N_NN PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'CC_CCS PR_PRP V_VM_VINF N_NN RD_PUNC CC_CCD N_NN RB QT_QTC N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG JJ N_NN V_VM_VINF N_NST RD_PUNC DM_DMD N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMD N_NN N_NN RD_PUNC RB V_VM_VINF N_NN V_VM_VNF RD_PUNC DM_DMD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN QT_QTC RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN QT_QTF N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC RD_PUNC N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD RB V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD DM_DMR N_NN QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN N_NN RD_PUNC V_VM_VNG N_NN V_VM_VNF RD_PUNC V_VM_VNF QT_QTF V_VM_VNF N_NN QT_QTF N_NN N_NN RD_PUNC',
#  'N_NN N_NN QT_QTF N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD N_NN N_NN V_VM_VNF RD_PUNC RB N_NN V_VM_VNG V_VM_VNF V_VM_VNF N_NN RB V_VM_VNF N_NN N_NN DM_DMR N_NN V_VM_VNG N_NN RD_PUNC',
#  'V_VM_VNG RD_PUNC RD_PUNC N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC N_NN N_NN V_VM_VINF V_VM_VF RD_PUNC',
#  'CC_CCD RB V_VM_VNF PR_PRP N_NN V_VM_VNG PSP V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN PR_PRP N_NN PR_PRP N_NN RB V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST V_VM_VNF RB RP_NEG RD_PUNC N_NN V_VM_VINF N_NN RB JJ N_NN N_NN V_VM_VNG PSP RB V_VM_VNF N_NN RB V_VM_VNF V_VM_VF RD_PUNC',
#  'RP_RPD V_VM_VNF N_NN RD_PUNC N_NN N_NN N_NN V_VM_VINF N_NN N_NNP PR_PRP N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC',
#  'N_NN N_NN V_VM_VNF RP_RPD N_NN PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP RD_PUNC RD_PUNC N_NN CC_CCS V_VM_VNF CC_CCS N_NN RD_PUNC',
#  'RP_INTF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN RD_PUNC V_VM_VF RD_PUNC',
#  'N_NST V_VM_VINF N_NN DM_DMR N_NN JJ N_NN JJ N_NN N_NN N_NN N_NN V_VM_VNF N_NN RB N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN CC_CCS V_VM_VNF N_NN RD_PUNC',
#  'RB V_VM_VINF N_NN V_VM_VNG RD_PUNC',
#  'RB V_VM_VNF N_NN N_NN V_VM_VINF N_NN RD_PUNC DM_DMR N_NN N_NN RP_INTF V_VM_VNF RD_PUNC N_NNP V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN RP_RPD N_NN N_NN N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTF N_NN N_NN QT_QTC PSP JJ N_NN N_NN RP_RPD N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'DM_DMD N_NN RD_PUNC N_NNP RD_PUNC QT_QTC RD_PUNC RB V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTF N_NN N_NN N_NN PSP N_NN RP_RPD DM_DMR N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN JJ N_NN N_NN N_NN N_NN RP_RPD PR_PRP N_NN V_VM_VINF N_NST N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN V_VM_VNF N_NST JJ N_NN N_NN RD_PUNC',
#  'PR_PRP RP_INTF JJ N_NN N_NN RD_PUNC',
#  'N_NN CC_CCD N_NN N_NN N_NN N_NST RB V_VM_VINF N_NN CC_CCD N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN V_VM_VNG PSP N_NN N_NN PR_PRC V_VM_VNG RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN RD_PUNC N_NN N_NN N_NN PSP V_VM_VINF N_NN N_NN DM_DMR N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NST QT_QTC N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN N_NN N_NN N_NN QT_QTC V_VM_VNF V_VAUX RD_PUNC',
#  'PR_PRP N_NN N_NN PR_PRP N_NN N_NN N_NN V_VM_VINF N_NN PSP QT_QTC N_NN N_NN DM_DMD N_NST QT_QTC N_NN PSP N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN V_VM_VNF N_NN QT_QTC N_NN RB N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMQ RP_RPD QT_QTF N_NN N_NN N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VINF RB N_NN JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN QT_QTC PSP N_NN N_NN N_NN V_VM_VNF PR_PRP JJ N_NN JJ N_NN N_NN PSP RD_PUNC CC_CCD N_NN PSP N_NN RD_PUNC PSP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF V_VM_VINF N_NN N_NN QT_QTC N_NN N_NN PSP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN V_VM_VNF N_NN N_NN N_NN QT_QTC N_NN N_NST V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NST RD_PUNC N_NN N_NN V_VM_VNF V_VM_VNF N_NN RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'DM_DMR QT_QTC N_NN N_NN N_NN V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF N_NN N_NN RP_RPD DM_DMD N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN RD_PUNC N_NN N_NN N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF QT_QTC N_NN RB RB V_VM_VF RD_PUNC',
#  'N_NN N_NN RP_RPD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN QT_QTF V_VM_VNF N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN V_VM_VNF V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN QT_QTF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF JJ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG RD_PUNC N_NN RD_PUNC N_NN N_NN JJ N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_SYM N_NN V_VM_VNF N_NN RD_PUNC RD_PUNC N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VNF CC_CCS RB V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VNF V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN V_VM_VINF N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN RP_RPD N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN RD_PUNC V_VM_VINF V_VM_VNF RD_PUNC RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NST RD_PUNC N_NN N_NN N_NN RD_PUNC N_NN V_VM_VINF N_NN N_NN N_NN QT_QTC N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN V_VM_VINF N_NN RP_RPD N_NN RD_PUNC',
#  'DM_DMQ RP_RPD N_NN V_VM_VNG N_NN V_VM_VINF N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VINF N_NN N_NN V_VM_VNF N_NN N_NN N_NN N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMR N_NN N_NN N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN QT_QTC RD_PUNC QT_QTC RD_PUNC QT_QTC N_NN JJ N_NN N_NN N_NN N_NN RB QT_QTC N_NN N_NN V_VM_VNF DM_DMR N_NN N_NN V_VM_VNF V_VM_VNF N_NN N_NN DM_DMD N_NN DM_DMD RB N_NN RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN PR_PRP N_NN N_NN N_NN N_NN N_NN N_NN QT_QTC N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC QT_QTC N_NN DM_DMD RB V_VM_VNF N_NN N_NN N_NN V_VM_VINF N_NN V_VM_VINF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN QT_QTC N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VNF DM_DMR N_NN QT_QTC N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN RP_RPD DM_DMR JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VNF N_NN N_NN N_NN QT_QTC N_NN N_NST V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_SYM QT_QTC RD_SYM N_NN N_NN RD_SYM QT_QTC RD_SYM N_NN N_NNP RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP N_NN N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VNF RD_PUNC PR_PRP RB N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN QT_QTC RD_PUNC N_NN JJ N_NN N_NN PSP N_NN PSP N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN RD_PUNC JJ N_NN N_NN V_VM_VNF JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN PSP RD_PUNC N_NN N_NN PSP N_NN PSP N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN QT_QTC N_NN RB N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN JJ N_NN N_NN N_NN QT_QTC N_NN RB RB N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP N_NN V_VM_VINF V_VM_VNF PR_PRP N_NN N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP N_NN RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VINF N_NN N_NN RB V_VM_VNF PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VINF N_NN N_NN QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN N_NN V_VM_VNG N_NN RD_PUNC V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC RD_PUNC N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VNF V_VM_VNF RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VNF N_NN RD_PUNC',
#  'N_NN N_NN JJ N_NN N_NN N_NN N_NN N_NN V_VM_VNF RD_PUNC JJ N_NN N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF V_VAUX RB V_VM_VF RD_PUNC',
#  'V_VM_VNF N_NN RB QT_QTC RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'RB N_NN N_NN RD_PUNC N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN RB V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG PSP RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNG RD_PUNC N_NN RD_PUNC N_NN JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP N_NNP RD_PUNC N_NN V_VM_VINF N_NST RP_RPD N_NN QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VINF N_NN RD_PUNC N_NN RB N_NN N_NN V_VM_VNF RD_PUNC PR_PRP N_NST V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VNF N_NN RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN RD_PUNC N_NN N_NN V_VM_VNF N_NST N_NN V_VM_VNF RD_PUNC N_NN N_NN RB CC_CCD N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN RD_PUNC N_NN V_VM_VNF N_NN JJ N_NN N_NN V_VM_VNF RD_PUNC N_NN V_VM_VINF V_VM_VNF RD_PUNC V_VM_VINF N_NN V_VM_VNF V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN N_NN N_NN RP_RPD RP_INTF N_NN RD_PUNC',
#  'N_NN N_NN PSP V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN V_VM_VINF N_NN RP_INTF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC PR_PRP N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN N_NN RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC N_NN QT_QTC N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RB V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN V_VM_VINF N_NN N_NN QT_QTC RD_PUNC QT_QTC RD_PUNC QT_QTC RD_PUNC QT_QTC RD_PUNC QT_QTC RP_RPD RB V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NN QT_QTC N_NN N_NN N_NN CC_CCD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN QT_QTC N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN N_NN QT_QTO N_NN CC_CCD N_NN N_NN RD_PUNC DM_DMQ V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN N_NN QT_QTC N_NN V_VM_VF RD_PUNC',
#  'RB PR_PRP N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'RP_RPD PR_PRP N_NN V_VM_VNF N_NN N_NN V_VM_VINF N_NST V_VM_VNF N_NN N_NST N_NN PR_PRP V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NST N_NN N_NN V_VM_VNF N_NN N_NST JJ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN V_VM_VINF N_NN N_NN N_NN V_VM_VINF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF RP_RPD JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN V_VM_VNF PR_PRP N_NN N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NNP N_NN N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NN RD_PUNC N_NN N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN PSP N_NN V_VM_VNF N_NN RD_PUNC',
#  'N_NN RB N_NN V_VM_VNF V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN V_VM_VNF PR_PRP V_VM_VF RD_PUNC',
#  'N_NN DM_DMD N_NN RB N_NN PSP PR_PRP N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN N_NN RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RB V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN N_NST V_VM_VINF N_NN RD_PUNC N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NNP RD_PUNC N_NN V_VM_VINF N_NST N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN PSP N_NN V_VM_VINF N_NN N_NN PR_PRP N_NN V_VM_VNF JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF N_NN QT_QTC N_NN N_NN N_NN V_VM_VNF PR_PRP RB V_VM_VNG RD_PUNC N_NN N_NN N_NN RD_PUNC',
#  'N_NN PR_PRP CC_CCD N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VINF N_NN V_VM_VNG RP_RPD N_NN N_NN QT_QTC RD_PUNC',
#  'N_NN N_NN DM_DMQ QT_QTC N_NN N_NN RD_PUNC N_NN V_VM_VNF RD_PUNC JJ N_NN N_NN V_VM_VNG V_VM_VNF PR_PRP V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF RD_PUNC DM_DMD N_NN N_NN N_NN V_VM_VNG V_VM_VNF RD_PUNC PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN',
#  'QT_QTC N_NN N_NN RD_PUNC N_NN RD_PUNC DM_DMD JJ N_NN PR_PRP PR_PRP N_NN JJ N_NN PSP V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VNF RD_PUNC QT_QTC N_NST QT_QTC N_NN V_VM_VF RD_PUNC',
#  'V_VM_VNF N_NN RD_PUNC N_NN PSP V_VM_VF RD_PUNC',
#  'DM_DMD RB V_VM_VINF N_NN RD_PUNC N_NNP RD_PUNC N_NNP RD_PUNC RD_PUNC N_NNP RD_PUNC N_NN N_NNP RD_PUNC N_NNP RD_PUNC CC_CCS_UT RD_PUNC N_NNP N_NN RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC N_NNP N_NN RD_PUNC N_NNP RD_PUNC CC_CCD RD_PUNC N_NNP N_NN RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC N_NST N_NNP RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC N_NNP N_NN RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC V_VM_VF RD_PUNC',
#  'PR_PRP N_NN PSP V_VM_VNF N_NN QT_QTF V_VM_VF RD_PUNC',
#  'QT_QTF N_NN N_NN RP_RPD V_VM_VF RD_PUNC',
#  'N_NN QT_QTF RP_CL V_VM_VF RD_PUNC',
#  'RP_RPD N_NN QT_QTC RP_RPD V_VM_VF RD_PUNC',
#  'QT_QTF JJ N_NN PSP DM_DMD N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN JJ N_NN N_NNP N_NNP N_NNP V_VM_VF RD_PUNC',
#  'PR_PRP PR_PRP PSP N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF RD_PUNC RB V_VM_VNF RD_PUNC N_NN RB N_NN V_VM_VNF N_NN N_NN V_VM_VINF N_NNP N_NN RD_PUNC PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NNP N_NN RD_PUNC N_NNP V_VM_VINF N_NN V_VM_VNF RD_PUNC PR_PRP N_NN N_NN V_VM_VINF QT_QTC N_NN N_NN RD_PUNC',
#  'N_NN N_NST PR_PRP N_NN V_VM_VNF N_NN N_NN N_NN RD_PUNC N_NN RP_RPD V_VM_VNF RD_PUNC N_NN V_VM_VNG V_VM_VF RD_PUNC',
#  'N_NST RB RP_NEG RD_PUNC',
#  'JJ N_NN N_NN N_NN RD_PUNC N_NN RD_PUNC N_NN RB N_NN RD_PUNC N_NN RD_PUNC PSP JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN JJ N_NN V_VM_VINF N_NN N_NN V_VM_VF RD_PUNC',
#  'RB N_NN N_NN V_VM_VNF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF V_VM_VNF RD_PUNC RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC RD_PUNC N_NNP RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VNF RD_PUNC JJ N_NN N_NN N_NN RB V_VM_VNF RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC N_NN JJ N_NN V_VM_VNF RD_PUNC N_NN N_NN RD_PUNC DM_DMD N_NN V_VM_VNF N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP JJ N_NN V_VM_VF RD_PUNC',
#  'DM_DMQ N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NNP V_VM_VF RD_PUNC',
#  'CC_CCS N_NN N_NN N_NN RD_PUNC',
#  'N_NNP N_NN RD_PUNC N_NN RP_INTF N_NN RD_PUNC',
#  'PR_PRP N_NST N_NN N_NN V_VM_VNF N_NN RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC N_NNP RD_PUNC CC_CCD N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NNP RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN V_VM_VNF PR_PRP JJ N_NN RD_PUNC',
#  'PR_PRP N_NNP N_NNP V_VM_VF RD_PUNC',
#  nan,
# ...
#  'QT_QTC RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NN N_NN V_VM_VNF N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NST N_NN RB N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN JJ N_NNP N_NN RD_PUNC N_NN RD_PUNC RD_PUNC',
#  'DM_DMD N_NN N_NST QT_QTC V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN RB RB V_VM_VNF QT_QTC RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NN RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RD_PUNC RD_PUNC N_NN RD_PUNC N_NN RP_RPD N_NN V_VM_VNF JJ N_NN V_VM_VNF N_NN N_NN N_NN CC_CCS_UT N_NN RD_PUNC',
#  'N_NN V_VM_VINF N_NN',
#  'QT_QTF RD_PUNC N_NN N_NN V_VM_VNF V_VM_VNF N_NST N_NN PSP V_VM_VNF V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN RD_PUNC N_NN N_NN V_VM_VNF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMD N_NN RB V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NNP RD_PUNC N_NN N_NN N_NN QT_QTC JJ N_NN RD_PUNC',
#  'N_NN N_NNP DM_DMD N_NN V_VM_VNF N_NN N_NN N_NNP PR_PRP V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN N_NNP PSP JJ N_NN RD_PUNC',
#  'N_NST N_NNP RD_SYM N_NN N_NN RD_SYM N_NNP V_VM_VF RD_PUNC',
#  'QT_QTC RD_PUNC N_NN V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN V_VM_VNF N_NNP N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMD N_NN PSP QT_QTF V_VM_VF RD_PUNC',
#  'N_NNP N_NN RD_PUNC N_NNP N_NN CC_CCS N_NNP RP_INTF N_NN RD_PUNC',
#  'PR_PRP N_NNP PSP V_VM_VF RD_PUNC',
#  'PR_PRP QT_QTC N_NN RB V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF N_NNP V_VM_VINF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN V_VM_VINF N_NN V_VM_VNF RD_PUNC N_NNP RD_PUNC N_NN QT_QTC RD_PUNC N_NNP N_NNP RD_PUNC N_NN RD_PUNC N_NN N_NNP RD_PUNC JJ N_NN N_NNP N_NN N_NN N_NNP V_VM_VNF N_NN RD_PUNC',
#  'N_NNP N_NN V_VM_VNF N_NN V_VM_VINF N_NN PR_PRP V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN N_NN N_NST N_NN V_VM_VNG N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN V_VM_VNF N_NNP RP_INTF V_VM_VF RD_PUNC',
#  'CC_CCD PR_PRP N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NNP N_NN N_NNP PSP N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN N_NNP N_NN N_NNP V_VM_VNF N_NNP PR_PRP V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN V_VM_VNF RD_PUNC N_NNP N_NN N_NNP N_NN RD_PUNC',
#  'N_NNP N_NN N_NN RD_PUNC',
#  'QT_QTC N_NN N_NNP N_NN PSP QT_QTC N_NNP V_VM_VNF N_NNP N_NN V_VM_VF RD_PUNC',
#  'PR_PRP DM_DMD N_NN N_NNP V_VM_VF RD_PUNC',
#  'PR_PRP V_VM_VNF N_NNP V_VM_VF RD_PUNC',
#  'N_NNP N_NN PSP N_NNP N_NN V_VM_VNF N_NNP N_NN V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NNP JJ RB V_VM_VF RD_PUNC',
#  'N_NN V_VM_VF N_NST N_NN JJ N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN RB RD_PUNC N_NN N_NN N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NST RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN V_VM_VNF N_NN PR_PRP N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VF JJ RB N_NN V_VM_VNF RB V_VM_VF RD_PUNC',
#  'N_NST PR_PRP V_VM_VNF PR_PRP RB V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NN QT_QTC RD_PUNC',
#  'PR_PRP N_NNP QT_QTC RD_PUNC',
#  'PR_PRP RP_INTF JJ N_NN RD_PUNC',
#  'PR_PRL V_VM_VINF N_NN V_VM_VNF RD_PUNC JJ JJ N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN JJ N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NST N_NN PSP RB N_NN RD_PUNC N_NN PR_PRP V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC JJ N_NN N_NN V_VM_VNF RD_PUNC V_VM_VINF N_NNP RB V_VM_VF RD_PUNC',
#  'DM_DMD N_NN RB V_VM_VF RD_PUNC',
#  'N_NN RD_SYM N_NN RD_SYM N_NN V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN PR_PRP N_NN V_VM_VF RD_PUNC',
#  'RD_PUNC V_VM_VNF N_NN RD_PUNC V_VM_VNF N_NN QT_QTC N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN QT_QTO N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'RD_PUNC JJ N_NN RD_PUNC N_NN N_NN V_VM_VNF V_VM_VNF RD_PUNC V_VM_VNF RP_NEG N_NN PSP RD_PUNC JJ N_NN DM_DMQ N_NN PR_PRP RD_PUNC N_NNP RD_PUNC',
#  'RD_PUNC N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VNF N_NN RD_PUNC',
#  'RD_PUNC N_NNP N_NN RD_PUNC N_NNP PR_PRP N_NN N_NN RD_PUNC V_VM_VNF N_NN RD_PUNC RD_PUNC N_NN RD_PUNC N_NN N_NN V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF V_VM_VF N_NN RD_PUNC',
#  'N_NN RD_PUNC RD_SYM N_NN RD_SYM N_NN RD_PUNC N_NN N_NN V_VM_VNF JJ N_NN V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NNP PSP N_NN RD_PUNC',
#  'N_NN RD_PUNC N_NN V_VM_VNF JJ N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'V_VM_VNF QT_QTF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC QT_QTC V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC PR_PRP V_VM_VNF N_NN RD_PUNC PR_PRP V_VM_VNF N_NN RD_PUNC N_NN V_VM_VNF N_NN RD_PUNC N_NNP N_NN RD_PUNC N_NN N_NN QT_QTO N_NN PSP N_NN V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'N_NNP RD_PUNC N_NNP N_NN RD_UNK RD_PUNC N_NN V_VM_VNF QT_QTO N_NN RD_PUNC RB V_VM_VNF N_NN N_NN RD_PUNC N_NNP N_NN N_NN RD_PUNC N_NNP RD_PUNC N_NN N_NN V_VM_VNF QT_QTC N_NN N_NN RD_UNK N_NN PSP V_VM_VF RD_PUNC',
#  'RD_PUNC N_NN V_VM_VNF RD_PUNC PR_PRP N_NN PR_PRP N_NST N_NN RD_PUNC V_VM_VNF RD_PUNC N_NNP QT_QTC N_NN N_NST V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN RD_PUNC PR_PRP N_NN RD_PUNC N_NN RD_PUNC',
#  'RD_PUNC N_NN N_NNP N_NN N_NN RD_PUNC',
#  'RD_PUNC N_NN N_NN V_VM_VF RD_PUNC',
#  'RD_PUNC N_NN N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VNF RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN RD_PUNC',
#  'N_NN N_NN V_VM_VINF N_NN N_NN N_NNP N_NNP N_NN N_NN QT_QTC N_NN N_NNP V_VM_VF RD_PUNC',
#  'DM_DMQ RD_PUNC',
#  'N_NNP PR_PRP RP_INTF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NNP PR_PRP JJ V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF N_NNP N_NN N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NNP QT_QTC N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NN RB V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NNP V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN RD_PUNC N_NNP RD_PUNC RD_PUNC PR_PRP N_NNP RP_INTF V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'PR_PRP N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NST QT_QTC RB RD_PUNC N_NNP N_NN JJ RB N_NN RD_SYM N_NNP RD_SYM N_NST JJ RB RD_PUNC N_NN N_NN PSP RD_PUNC DM_DMD N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RD_PUNC',
#  'CC_CCS N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN V_VM_VNF QT_QTF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'JJ N_NN RD_PUNC N_NNP RD_PUNC QT_QTC RD_PUNC',
#  'PR_PRP N_NN V_VM_VNF N_NN RD_PUNC',
#  'N_NN N_NN N_NN DM_DMD N_NN V_VM_VNF N_NN RP_INTF V_VM_VF RD_PUNC',
#  'V_VM_VNF N_NNP RP_INTF RP_INTF N_NN V_VM_VF RD_PUNC',
#  'V_VM_VNF RP_RPD RD_PUNC PR_PRP N_NN V_VM_VF RD_PUNC',
#  'RB V_VM_VNF JJ N_NN V_VM_VNF RD_PUNC JJ JJ N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN QT_QTC RD_PUNC',
#  'PR_PRP RD_PUNC N_NN RD_PUNC V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN RP_INTF N_NN CC_CCD N_NN V_VM_VNF JJ N_NN PR_PRP V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RD_PUNC N_NNP RD_PUNC RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF N_NN N_NN V_VM_VNF PR_PRP RP_INTF V_VM_VF RD_PUNC',
#  'QT_QTC N_NN N_NST V_VM_VNF RD_PUNC N_NN N_NN V_VM_VNF RD_PUNC N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC PR_PRP N_NN V_VM_VNF RD_PUNC N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NNP N_NN JJ N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NNP N_NN QT_QTC N_NN N_NST V_VM_VF RD_PUNC',
#  'N_NNP N_NN QT_QTC RP_CL N_NN N_NN V_VM_VF PR_PRP RD_PUNC',
#  'PR_PRP N_NN CC_CCD PR_PRPRD_PUNC',
#  'PR_PRP N_NN N_NNP RD_PUNC',
#  'N_NNP JJ N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC N_NNP RD_PUNC N_NN N_NN N_NN V_VM_VINF N_NN RD_PUNC',
#  'N_NN JJ N_NN V_VM_VINF N_NN N_NNP RD_PUNC N_NNP RD_PUNC',
#  'N_NNP N_NN N_NN N_NNP RD_PUNC',
#  'PR_PRP RB V_VM_VINF N_NN RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NNP N_NN RD_PUNC V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN PR_PRP N_NN V_VM_VNF PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC RD_PUNC N_NNP RD_PUNC N_NNP RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NST RD_PUNC N_NNP RD_PUNC PR_PRP V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMD N_NN V_VM_VNF PR_PRP PR_PRP N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC N_NNP RD_PUNC CC_CCD RP_INTF V_VM_VF RD_PUNC',
#  'N_NNP N_NNP N_NN V_VM_VINF N_NN PSP JJ N_NN V_VM_VNF RP_INTF N_NN N_NN RD_PUNC N_NNP RD_PUNC N_NN QT_QTC N_NN N_NST N_NNP RD_SYM N_NNP N_NN RD_SYM V_VM_VINF N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NN DM_DMQ N_NN V_VM_VNF RD_PUNC N_NN N_NN DM_DMQ V_VM_VNF RD_PUNC N_NN DM_DMQ V_VM_VNF RD_PUNC DM_DMQ N_NN V_VM_VNF RD_PUNC N_NN V_VM_VNF N_NN RD_PUNC N_NN V_VM_VNF N_NN RD_PUNC QT_QTF N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN QT_QTC N_NN N_NN QT_QTC N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC',
#  'N_NNP CC_CCD N_NN N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN N_NNP V_VM_VF RD_PUNC',
#  'N_NNP N_NN V_VM_VNF N_NST N_NN PSP V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC RD_PUNC RD_PUNC N_NNP RD_PUNC N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NNP N_NNP RP_INTF N_NN V_VM_VINF N_NN RD_PUNC',
#  'QT_QTF JJ N_NN RD_PUNC N_NN RD_PUNC N_NN N_NN N_NST V_VM_VF RD_PUNC',
#  'N_NST N_NN RD_PUNC N_NN RP_INTF N_NN V_VM_VF RD_PUNC',
#  'N_NST RD_PUNC N_NN RD_PUNC CC_CCS_UT N_NN V_VM_VINF N_NN RD_PUNC N_NNP RD_PUNC CC_CCS_UT N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NNP RP_INTF N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN PSP QT_QTC N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NNP V_VM_VF RD_PUNC',
#  'QT_QTF JJ RD_PUNC JJ N_NN V_VM_VNF QT_QTC N_NN N_NN RD_PUNC',
#  'PR_PRP N_NN N_NNP RD_PUNC',
#  'PR_PRP N_NN N_NNP RD_PUNC JJ N_NN RD_PUNC',
#  'N_NN N_NST V_VM_VF RD_PUNC',
#  'N_NNP N_NN V_VM_VNF RD_PUNC PR_PRP N_NN V_VM_VNF N_NNP V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VNF QT_QTC N_NN V_VM_VINF N_NN V_VM_VF RD_PUNC',
#  'N_NNP RD_PUNC N_NNP V_VM_VF RD_PUNC',
#  'N_NNP N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NNP PR_PRP N_NN V_VM_VNF RD_PUNC N_NN N_NST RP_RPD RD_PUNC N_NN N_NST V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NST N_NN N_NNP V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VINF N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN PR_PRP N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NST PSP PR_PRP N_NST PSP DM_DMD N_NN V_VM_VNF N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NNP N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC PR_PRP N_NN RB N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NNP DM_DMD N_NN N_NNP N_NNP N_NNP V_VM_VF RD_PUNC',
#  'PR_PRP N_NNP N_NN V_VM_VINF N_NN RD_PUNC',
#  'N_NN N_NNP V_VM_VNF RD_SYM QT_QTC RD_SYM PR_PRP N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NNP V_VM_VF RD_PUNC',
#  'N_NNP N_NNP RP_INTF N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NST N_NNP RD_PUNC N_NNP N_NN RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VINF N_NN N_NNP V_VM_VF RD_PUNC',
#  'DM_DMD N_NN RP_INTF QT_QTC N_NN N_NST V_VM_VNF RD_PUNC N_NN N_NN V_VM_VNF RB N_NN V_VM_VNF N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'CC_CCS_UT N_NNP N_NN N_NN N_NN N_NN RD_PUNC',
#  'N_NNP N_NN N_NN N_NN RD_PUNC',
#  'PR_PRP N_NNP N_NN V_VM_VINF N_NN RP_INTF V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RP_INTF V_VM_VF RD_PUNC',
#  'N_NNP N_NST N_NN PSP V_VM_VNF DM_DMD N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NNP N_NN PSP RB V_VM_VNF DM_DMD QT_QTC N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC',
#  'DM_DMD N_NN N_NN RP_INTF V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NN N_NST RP_INTF JJ N_NN RD_PUNC N_NNP RD_PUNC QT_QTC PSP RD_PUNC',
#  'PR_PRP V_VM_VINF N_NN V_VM_VINF PSP N_NN N_NST PSP RP_NEG RD_PUNC',
#  'N_NN QT_QTC N_NN N_NST N_NN PR_PRP N_NN N_NST V_VM_VINF N_NNP N_NN N_NN N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN QT_QTF V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NST N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN RB N_NN V_VM_VF RD_PUNC',
#  'N_NN QT_QTC V_VM_VF RD_PUNC',
#  'N_NN N_NST QT_QTC N_NN V_VM_VNF V_VAUX RD_PUNC',
#  'JJ N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'V_VM_VNF N_NN N_NN V_VM_VNF RB V_VM_VF RD_PUNC',
#  'QT_QTC N_NN V_VM_VF RD_PUNC',
#  'RD_PUNC N_NN N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN V_VM_VF RD_PUNC',
#  'N_NN RB V_VM_VF RD_PUNC',
#  'RD_PUNC JJ N_NN V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN V_VM_VNF QT_QTC N_NN RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC CC_CCS_UT V_VM_VF RD_PUNC',
#  'N_NN V_VM_VINF N_NN PR_PRP N_NN V_VM_VNF RB PR_PRP V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NST DM_DMD N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN DM_DMD N_NST RD_PUNC DM_DMD N_NST RD_PUNC N_NST RD_PUNC N_NST RB V_VM_VF RD_PUNC',
#  'RB V_VM_VF RD_PUNC',
#  'N_NST N_NN N_NST V_VM_VF RD_PUNC',
#  'RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC N_NN V_VM_VNF V_VM_VNF RB V_VM_VNF V_VAUX RD_PUNC',
#  'V_VM_VNF N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NST PR_PRP N_NN N_NN RD_PUNC N_NN N_NN RD_PUNC N_NN N_NN N_NN N_NN N_NN V_VM_VNF RD_PUNC N_NST V_VM_VNF RD_PUNC N_NST N_NN V_VM_VNF RD_PUNC N_NN RB V_VM_VNF RD_PUNC RB V_VM_VNF RD_PUNC N_NN V_VM_VNF RD_PUNC N_NN RB RD_PUNC N_NN RB V_VM_VNF V_VM_VNF V_VM_VF RD_PUNC',
#  'DM_DMQ V_VM_VNF RD_PUNC RB V_VM_VNF PR_PRP V_VM_VNF RD_PUNC DM_DMD N_NN V_VM_VNG RD_PUNC N_NN N_NN V_VM_VNG RD_PUNC N_NN V_VM_VNG RD_PUNC QT_QTF V_VM_VNF RP_INTF RB V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'RB V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC CC_CCD CC_CCD RD_PUNC N_NNP RD_PUNC N_NN RD_PUNC CC_CCD N_NN V_VM_VINF N_NN V_VM_VNF PR_PRP V_VM_VNF N_NN RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN RB V_VM_VNF V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC',
#  'V_VM_VNF N_NN RD_PUNC N_NN V_VM_VNF N_NN PR_PRP V_VM_VNF N_NN N_NN N_NN N_NN V_VM_VNF V_VM_VNF N_NN RD_PUNC N_NN V_VM_VF RD_PUNC',
#  'N_NN V_VM_VNF N_NN DM_DMD N_NN N_NN V_VM_VNF RD_PUNC DM_DMD N_NN N_NN PR_PRP V_VM_VNF RD_PUNC N_NN V_VM_VNF RD_PUNC V_VM_VNF RD_PUNC N_NN RD_PUNC N_NST N_NN V_VM_VNF RD_PUNC N_NST N_NN N_NN N_NN V_VM_VNF N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'RB N_NN N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NNP RD_PUNC N_NNP JJ N_NN V_VM_VNF V_VM_VF RD_PUNC',
#  'N_NN N_NN RD_PUNC RD_PUNC N_NN V_VM_VNF RD_PUNC N_NN N_NN N_NST PR_PRP N_NN N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP RD_PUNC PR_PRP N_NN JJ N_NN N_NN V_VM_VNF RD_PUNC V_VM_VNF PR_PRP V_VM_VINF N_NN PR_PRP N_NN V_VM_VNF N_NN N_NN RB V_VM_VF RD_PUNC',
#  'N_NN N_NST QT_QTC QT_QTC RP_CL N_NN RD_PUNC N_NN V_VM_VNF RD_PUNC N_NNP N_NN V_VM_VF RD_PUNC',
#  'PR_PRP V_VM_VNF N_NN RD_PUNC N_NNP RD_PUNC N_NNP RD_PUNC N_NNP N_NN N_NN V_VM_VNF N_NN N_NN V_VM_VNF RD_PUNC N_NN N_NN V_VM_VNF RD_PUNC N_NN V_VM_VNF N_NN V_VM_VNF RD_PUNC RB V_VM_VF RD_PUNC',
#  'V_VM_VF RD_PUNC',
#  'DM_DMD N_NN N_NN N_NN PR_PRP V_VM_VNF RB N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NN N_NN V_VM_VF RD_PUNC',
#  'RB V_VM_VNF RD_PUNC V_VM_VNF QT_QTC N_NN JJ RP_CL V_VM_VNG N_NN V_VM_VF RD_PUNC',
#  'N_NST N_NN QT_QTC V_VM_VF RD_PUNC',
#  'N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN V_VM_VF RD_PUNC',
#  'N_NST V_VM_VF PSP RD_PUNC N_NN RD_PUNC N_NN RD_PUNC N_NN V_VM_VNF RD_PUNC RB N_NN V_VM_VF RD_PUNC',
#  'RB V_VM_VNF RD_PUNC RD_PUNC RD_UNK RD_PUNC RD_UNK RD_PUNC N_NN RD_PUNC RD_UNK RD_PUNC RD_PUNC RD_PUNC N_NNP RD_PUNC N_NNP RD_PUNC CC_CCD N_NN V_VM_VNF PR_PRP V_VM_VNF N_NN N_NN V_VM_VNF V_VM_VNG N_NN RD_PUNC',
#  'N_NNP RD_PUNC N_NNP JJ N_NN V_VM_VNF RD_PUNC V_VM_VNF RD_PUNC DM_DMD N_NN N_NN N_NN V_VM_VNF V_VM_VNF N_NN RD_PUNC',
#  'QT_QTF RP_CL N_NN RD_PUNC N_NN N_NN V_VM_VNF QT_QTC N_NN N_NN N_NN RD_PUNC',
#  'N_NN N_NN RD_PUNC RD_PUNC DM_DMD N_NN N_NNP N_NN RD_PUNC',
#  'N_NNP N_NN V_VM_VNF N_NNP RD_PUNC N_NNP V_VM_VNF N_NNP N_NN RD_PUNC N_NN N_NN N_NN RD_PUNC',
#  'DM_DMD N_NST N_NNP V_VM_VNF JJ N_NN N_NN PR_PRP N_NN V_VM_VNF N_NNP V_VM_VNF V_VM_VF RD_PUNC',
#  'PR_PRP DM_DMD N_NN V_VM_VNF PR_PRP V_VM_VNF V_VM_VF RD_PUNC',
#  'PR_PRP DM_DMR N_NN RD_SYM N_NNP RD_PUNC N_NST N_NNP DM_DMD N_NN PSP V_VM_VNF RD_PUNC RB V_VM_VINF N_NNP N_NNP N_NNP V_VM_VNF N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NN N_NNP V_VM_VNF RD_PUNC N_NNP N_NNP V_VM_VNF RD_PUNC RB N_NN V_VM_VF RD_PUNC',
#  'N_NNP N_NNP N_NNP N_NNP RP_INTF N_NN N_NN RD_PUNC',
#  'QT_QTF QT_QTC N_NN PSP DM_DMD N_NN N_NN RD_SYM N_NN RP_RPD RD_SYM N_NN V_VM_VF RD_PUNC',
#  'PR_PRP N_NN RD_PUNC N_NN V_VM_VNF N_NNP RD_PUNC N_NNP JJ N_NN N_NN V_VM_VNF V_VM_VNF PR_PRP PSP V_VM_VINF V_VM_VNF RD_PUNC V_VM_VF RD_PUNC',
#  'PR_PRP N_NST N_NN N_NN V_VM_VNF N_NN V_VM_VNF PR_PRP RD_PUNC',
#  ...]

# %%
uni_grams = [b for l in list_strings for b in str(l).split(" ")[:-1]]

# we are finding out unigrams here
# first, we are taking each term from the list_strings as variable named 'l'
# second, we convert l as string and split it with spaces. now, we get all tags.
# take first tag as variable 'b' and append it to the list 'unigrams' sequentially one by one until the last tag is exhausted.
# thus we get all the tags as the list of unigrams

print(uni_grams)
# Out:
# ['QT_QTC', 'RD_SYM', 'N_NN', 'V_VM_VNF', 'N_NST', 'N_NN', 'PR_PRP', 'V_VM_VINF', 'N_NN', 'N_NN', 'V_VM_VNF', 'N_NN', 'N_NN', 'N_NN', 'RB', 'V_VM_VF', 'N_NN', 'N_NN', 'V_VM_VNF', 'N_NN', 'PR_PRQ', 'V_VM_VNF', 'V_VAUX', 'PR_PRP', 'N_NN', 'QT_QTF', 'N_NN', 'QT_QTC', 'RD_SYM', 'N_NN', 'N_NN', 'RD_PUNC', 'N_NN', 'N_NN', 'RD_PUNC', 'N_NN', 'V_VM_VNF', 'N_NN', 'N_NN', 'PR_PRP', 'N_NN', 'V_VM_VF', 'QT_QTC', 'RD_SYM', 'N_NN', 'JJ', 'N_NN', 'V_VM_VNF', 'N_NN', 'PR_PRQ', 'N_NN', 'N_NN', 'N_NN', 'V_VM_VNF', 'PR_PRP', 'N_NN', 'QT_QTF', 'V_VM_VF', 'DM_DMD', 'N_NN', 'DM_DMD', 'N_NN', 'V_VM_VINF', 'N_NN', 'N_NN', 'PR_PRP', 'V_VM_VINF', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'V_VM_VINF', 'JJ', 'N_NN', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'V_VM_VNF', 'V_VAUX', 'QT_QTC', 'RD_SYM', 'N_NST', 'V_VM_VINF', 'N_NN', 'V_VM_VNF', 'N_NNP', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'V_VM_VF', 'N_NN', 'N_NN', 'N_NN', 'QT_QTF', 'N_NN', 'CC_CCD', 'N_NN', 'V_VM_VF', 'PR_PRP', 'N_NN', 'V_VM_VINF', 'N_NN', 'N_NN', 'RP_RPD', 'N_NN', 'V_VM_VF', 'N_NN', 'N_NN', 'V_VM_VNF', 'N_NN', 'N_NN', 'N_NN', 'QT_QTF', 'N_NN', 'V_VM_VINF', 'N_NN', 'V_VM_VNF', 'V_VM_VF', 'N_NN', 'N_NN', 'V_VM_VNG', 'JJ', 'N_NN', 'N_NN', 'DM_DMD', 'N_NN', 'V_VM_VF', 'N_NN', 'N_NN', 'V_VM_VNG', 'JJ', 'N_NN', 'N_NN', 'N_NN', 'RB', 'V_VM_VNF', 'V_VAUX', 'QT_QTC', 'RD_SYM', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'PSP', 'N_NN', 'V_VM_VF', 'N_NN', 'N_NN', 'V_VM_VNF', 'N_NN', 'N_NN', 'RP_RPD', 'QT_QTC', 'N_NN', 'V_VM_VNG', 'RP_RPD', 'RP_INTF', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'RP_RPD', 'N_NN', 'QT_QTC', 'N_NN', 'V_VM_VNF', 'N_NN', 'RP_INTF', 'N_NN', 'N_NNP', 'N_NN', 'N_NN', 'RD_PUNC', 'N_NN', 'RD_PUNC', 'N_NN', 'QT_QTF', 'N_NN', 'V_VM_VNF', 'DM_DMD', 'N_NN', 'PR_PRP', 'V_VM_VF', 'N_NN', 'RD_PUNC', 'N_NN', 'RD_PUNC', 'RB', 'RB', 'N_NN', 'N_NN', 'V_VM_VNF', 'N_NN', 'V_VAUX', 'PR_PRP', 'QT_QTC', 'N_NST', 'N_NN', 'V_VM_VF', 'N_NN', 'V_VM_VINF', 'N_NN', 'PSP', 'RP_RPD', 'N_NN', 'PR_PRP', 'PR_PRP', 'N_NN', 'V_VM_VNF', 'V_VM_VF', 'N_NN', 'RD_PUNC', 'N_NN', 'N_NN', 'V_VM_VNG', 'RD_PUNC', 'N_NN', 'N_NN', 'V_VM_VNG', 'RD_PUNC', 'N_NN', 'V_VM_VNG', 'RD_PUNC', 'N_NN', 'V_VM_VNG', 'JJ', 'N_NN', 'N_NN', 'N_NN', 'PR_PRP', 'N_NN', 'V_VM_VINF', 'N_NN', 'PSP', 'V_VM_VF', 'PSP', 'N_NN', 'N_NN', 'PSP', 'PR_PRP', 'N_NN', 'V_VM_VF', 'N_NN', 'N_NN', 'N_NN', 'RD_PUNC', 'N_NN', 'N_NN', 'N_NST', 'V_VM_VINF', 'N_NN', 'V_VM_VNF', 'QT_QTC', 'RD_PUNC', 'N_NN', 'N_NN', 'RD_SYM', 'DM_DMR', 'RD_SYM', 'N_NN', 'N_NN', 'RD_SYM', 'N_NN', 'RD_SYM', 'N_NN', 'N_NN', 'N_NN', 'RD_SYM', 'N_NN', 'RD_SYM', 'N_NN', 'N_NN', 'RD_SYM', 'N_NN', 'RD_SYM', 'N_NN', 'QT_QTC', 'RD_PUNC', 'N_NN', 'QT_QTC', 'RD_PUNC', 'N_NN', 'QT_QTC', 'RD_PUNC', 'N_NN', 'QT_QTC', 'RD_PUNC', 'N_NN', 'N_NN', 'QT_QTF', 'N_NN', 'N_NN', 'PSP', 'RD_PUNC', 'PR_PRP', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'PSP', 'RD_PUNC', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'V_VM_VF', 'QT_QTF', 'JJ', 'N_NN', 'V_VM_VNF', 'QT_QTF', 'JJ', 'N_NN', 'V_VM_VF', 'RB', 'QT_QTF', 'N_NN', 'N_NN', 'RP_RPD', 'RB', 'V_VM_VF', 'PR_PRP', 'PSP', 'N_NNP', 'N_NN', 'N_NN', 'N_NN', 'QT_QTC', 'PSP', 'QT_QTC', 'PSP', 'DM_DMD', 'N_NN', 'N_NN', 'RB', 'V_VM_VF', 'DM_DMQ', 'JJ', 'N_NN', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'QT_QTF', 'JJ', 'N_NN', 'CC_CCS', 'N_NN', 'V_VM_VNF', 'N_NN', 'QT_QTF', 'V_VM_VF', 'QT_QTF', 'N_NN', 'V_VM_VNF', 'JJ', 'N_NN', 'N_NN', 'QT_QTC', 'QT_QTC', 'JJ', 'N_NN', 'N_NN', 'RP_RPD', 'PR_PRP', 'N_NN', 'N_NN', 'RD_PUNC', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'V_VM_VF', 'N_NST', 'DM_DMD', 'N_NN', 'JJ', 'N_NN', 'N_NN', 'V_VM_VF', 'QT_QTC', 'RD_PUNC', 'JJ', 'N_NN', 'V_VM_VINF', 'N_NN', 'V_VM_VNF', 'PSP', 'N_NN', 'V_VM_VF', 'QT_QTC', 'RD_PUNC', 'JJ', 'N_NN', 'N_NN', 'N_NN', 'N_NN', 'N_NST', 'V_VM_VINF', 'N_NN', 'V_VM_VINF', 'N_NN', 'RB', 'V_VM_VF', 'QT_QTC', 'RD_PUNC', 'DM_DMR', 'N_NN', 'QT_QTC', 'N_NN', 'V_VM_VNF', 'RD_PUNC', 'DM_DMD', 'N_NN', 'N_NN', 'QT_QTC', 'V_VM_VF', 'QT_QTC', 'RD_PUNC', 'N_NN', 'N_NN', 'N_NN', 'V_VM_VINF', 'N_NN', 'V_VM ...

# %%
print(len(uni_grams))

# we get the number of unigrams present in the corpus

print('Number of Unigrams present in the whole corpus - ', len(uni_grams))
# Out:
# 107133
# Number of Unigrams present in the whole corpus -  107133

# %%
from collections import Counter

count = dict(Counter(uni_grams))
print(count)

# we get the frequency of occurrences of each tags/unigrams
# Out:
# {'QT_QTC': 4113, 'RD_SYM': 1480, 'N_NN': 45540, 'V_VM_VNF': 10136, 'N_NST': 1824, 'PR_PRP': 4837, 'V_VM_VINF': 1696, 'RB': 2772, 'V_VM_VF': 6419, 'PR_PRQ': 2, 'V_VAUX': 487, 'QT_QTF': 679, 'RD_PUNC': 12161, 'JJ': 2373, 'DM_DMD': 1172, 'N_NNP': 3914, 'CC_CCD': 1072, 'RP_RPD': 1107, 'V_VM_VNG': 493, 'PSP': 1831, 'RP_INTF': 408, 'DM_DMR': 712, 'DM_DMQ': 949, 'CC_CCS': 110, 'CC_CCS_UT': 343, 'RP_CL': 67, 'RP_NEG': 164, 'QT_QTO': 134, 'PR_PRC': 1, 'RP_INJ': 48, 'RD_UNK': 40, 'PR_PRL': 21, 'RD_ECH': 3, '': 8, 'NN': 17}

# %%
print(len(count))

# This gives us how many tags we have in our corpus

print('Number of tags in our corpus', len(count))
# Out:
# 35
# Number of tags in our corpus 35

# %%
sorted_count = {k: v for k, v in sorted(count.items(), key=lambda item: item[1], reverse=True)}

print(sorted_count)

# we have sorted our tags based in the decresing order of frequency.
# we have 'N_NN' tag occurring highest number of times
# Out:
# {'N_NN': 45540, 'RD_PUNC': 12161, 'V_VM_VNF': 10136, 'V_VM_VF': 6419, 'PR_PRP': 4837, 'QT_QTC': 4113, 'N_NNP': 3914, 'RB': 2772, 'JJ': 2373, 'PSP': 1831, 'N_NST': 1824, 'V_VM_VINF': 1696, 'RD_SYM': 1480, 'DM_DMD': 1172, 'RP_RPD': 1107, 'CC_CCD': 1072, 'DM_DMQ': 949, 'DM_DMR': 712, 'QT_QTF': 679, 'V_VM_VNG': 493, 'V_VAUX': 487, 'RP_INTF': 408, 'CC_CCS_UT': 343, 'RP_NEG': 164, 'QT_QTO': 134, 'CC_CCS': 110, 'RP_CL': 67, 'RP_INJ': 48, 'RD_UNK': 40, 'PR_PRL': 21, 'NN': 17, '': 8, 'RD_ECH': 3, 'PR_PRQ': 2, 'PR_PRC': 1}

# %%
f_data = pd.DataFrame([sorted_count])
# we are converting our sorted frequencies as a pandas dataframe for easy visualization

f_data = f_data.T
# we are transposing our data matrix for column view

f_data = f_data.reset_index()
# we are resetting our index to default values

f_data.columns = ['Uni_grams','Frequency']
# we are addding column names for easy understanding of the columns in our unigram frequency dataframe

f_data[:]
# we visualize the whole data
# Out:
#     Uni_grams  Frequency
# 0        N_NN      45540
# 1     RD_PUNC      12161
# 2    V_VM_VNF      10136
# 3     V_VM_VF       6419
# 4      PR_PRP       4837
# 5      QT_QTC       4113
# 6       N_NNP       3914
# 7          RB       2772
# 8          JJ       2373
# 9         PSP       1831
# 10      N_NST       1824
# 11  V_VM_VINF       1696
# 12     RD_SYM       1480
# 13     DM_DMD       1172
# 14     RP_RPD       1107
# 15     CC_CCD       1072
# 16     DM_DMQ        949
# 17     DM_DMR        712
# 18     QT_QTF        679
# 19   V_VM_VNG        493
# 20     V_VAUX        487
# 21    RP_INTF        408
# 22  CC_CCS_UT        343
# 23     RP_NEG        164
# 24     QT_QTO        134
# 25     CC_CCS        110
# 26      RP_CL         67
# 27     RP_INJ         48
# 28     RD_UNK         40
# 29     PR_PRL         21
# 30         NN         17
# 31                     8
# 32     RD_ECH          3
# 33     PR_PRQ          2
# 34     PR_PRC          1

# %%
f_data.to_csv(r'C:\Users\sures\Downloads\Downloads_1\Nagaraj_Anna\Final_Files\Unigrams\uni_gram_freq.csv')

# we are saving our new unigram frequency dataset into our drive after converting it into csv file.
